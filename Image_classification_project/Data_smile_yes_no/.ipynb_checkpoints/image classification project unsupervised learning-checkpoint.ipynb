# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
SmileImages = os.listdir('/home/shivalika/Downloads/Data_smile_yes_no/Data_smile_yes_no/Smile_Yes')
print ("Number of Smile images - ",str(len(SmileImages)))

NosmileImages = os.listdir('/home/shivalika/Downloads/Data_smile_yes_no/Data_smile_yes_no/Smile_No')
print ("Number of Nosmile images - ",str(len(NosmileImages)))
# Out:
# Number of Smile images -  200
# Number of Nosmile images -  200

# %%
SmileFilename = '/home/shivalika/Downloads/Data_smile_yes_no/Data_smile_yes_no/Smile_Yes/'+SmileImages[1]
Simage = Image.open(SmileFilename)
Simage
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=162x193 at 0x7F8D80E26D30>

# %%
NoSmileFilename = '/home/shivalika/Downloads/Data_smile_yes_no/Data_smile_yes_no/Smile_No/'+NosmileImages[1]
NSimage = Image.open(NoSmileFilename)
NSimage
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=162x193 at 0x7F8D80E26940>
